# %%
# import necessary libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot

# %%
# reading the data 
df = pd.read_csv('concrete.csv')

# %%
df
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# 1        23.51
# 2        29.22
# 3        45.85
# ...

# %%
df.info() # basic info of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cement        1030 non-null   float64
#  1   slag          1030 non-null   float64
#  2   ash           1030 non-null   float64
#  3   water         1030 non-null   float64
#  4   superplastic  1030 non-null   float64
#  5   coarseagg     1030 non-null   float64
#  6   fineagg       1030 non-null   float64
#  7   age           1030 non-null   int64
#  8   strength      1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
df.describe(include='all') # getting insights of the complete data
# Out:
#             cement         slag          ash        water  superplastic  \
# count  1030.000000  1030.000000  1030.000000  1030.000000   1030.000000
# mean    281.167864    73.895825    54.188350   181.567282      6.204660
# std     104.506364    86.279342    63.997004    21.354219      5.973841
# min     102.000000     0.000000     0.000000   121.800000      0.000000
# 25%     192.375000     0.000000     0.000000   164.900000      0.000000
# 50%     272.900000    22.000000     0.000000   185.000000      6.400000
# 75%     350.000000   142.950000   118.300000   192.000000     10.200000
# max     540.000000   359.400000   200.100000   247.000000     32.200000
#
#          coarseagg      fineagg          age     strength
# count  1030.000000  1030.000000  1030.000000  1030.000000
# mean    972.918932   773.580485    45.662136    35.817961
# std      77.753954    80.175980    63.169912    16.705742
# min     801.000000   594.000000     1.000000     2.330000
# ...

# %% [markdown]
# some columns are with 0 values here ignore that because concrete is a mixute of combination granules,
# when columns are having 0 values it also means that the concrete is not mixed at the mixture of situation

# %%
df[df['ash']==0].count() # some columns are with 0 values
# Out:
# cement          566
# slag            566
# ash             566
# water           566
# superplastic    566
# coarseagg       566
# fineagg         566
# age             566
# strength        566
# dtype: int64

# %%
df[df['slag']==0].count()
# Out:
# cement          471
# slag            471
# ash             471
# water           471
# superplastic    471
# coarseagg       471
# fineagg         471
# age             471
# strength        471
# dtype: int64

# %%
df[df['superplastic']==0].count()
# Out:
# cement          379
# slag            379
# ash             379
# water           379
# superplastic    379
# coarseagg       379
# fineagg         379
# age             379
# strength        379
# dtype: int64

# %%
df.isna().sum() #no null values
# Out:
# cement          0
# slag            0
# ash             0
# water           0
# superplastic    0
# coarseagg       0
# fineagg         0
# age             0
# strength        0
# dtype: int64

# %%
sns.heatmap(df.corr(), annot =True) # correlation b/w columns
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
#        'fineagg', 'age', 'strength'],
#       dtype='object')

# %%
a4_dims = (12,5)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.boxplot(data=df) # boxplot of all columns which can identify the strange patterns of data ie,outliers
# Out:
# <AxesSubplot:>

# %%
a4_dims = (12,5)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.scatterplot(data=df) # u can observe a wide-spread of data there is no linearly spread of data
# Out:
# <AxesSubplot:>

# %%
sns.set_style('ticks')
sns.pairplot(df,  diag_kind = 'kde', kind='scatter', palette='husl')
plt.show() # pair plot gives that how distribution of data is being done and its relationship with other features

# observe all the plots clearly, distinct patterns can be seen

# %%
df.plot.kde() # the plot goes with density of data distribution
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### density distributions of data

# %%
sns.kdeplot(data=df, x='cement')
# Out:
# <AxesSubplot:xlabel='cement', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='slag')
# Out:
# <AxesSubplot:xlabel='slag', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='ash')

# it is a bimodal kind of plot because of two peaks
# Out:
# <AxesSubplot:xlabel='ash', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='water') 

# its a kind of multimodal because of peaks or bumps in the plot of concrete data
# Out:
# <AxesSubplot:xlabel='water', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='strength')
# Out:
# <AxesSubplot:xlabel='strength', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='superplastic')

# bimodal plot because of the two bumps and distribution of data is varied largely
# Out:
# <AxesSubplot:xlabel='superplastic', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='fineagg')
# Out:
# <AxesSubplot:xlabel='fineagg', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='coarseagg')
# Out:
# <AxesSubplot:xlabel='coarseagg', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
#        'fineagg', 'age', 'strength'],
#       dtype='object')

# %%
sns.displot(data=df, stat = 'probability')

# %%
sns.displot(data=df, x='cement',y='water', stat = 'density')

# %%
sns.displot(df, x='water')

# %%
sns.displot(df, x="superplastic")

# %%
sns.displot(df, x="cement", kind="kde", bw_adjust=1)

# %%
sns.displot(df, x="strength",y = 'age', kind="kde", cmap='Greens', shade = True)
plt.show()

# darker color because of the density of data
# Out:
# C:\Users\ironm\anaconda3\lib\site-packages\seaborn\distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'shade'
#   cset = contour_func(

# %%
sns.displot(df, x="age")

# %%
sns.displot(df, x = 'cement', y ='age',binwidth=(2, .5), cbar=True)

# %%
sns.displot(df, x = 'strength', y ='age', binwidth=(2, .5), cbar=True)

# %%
sns.displot(df, x = 'strength', y ='age',log_scale=(True, False))

# %%
g=sns.PairGrid(df) # showing the pairwise relationships b/w features
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
a4_dims = (10,5)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.barplot(data=df) # as we discussed 'coarseagg' and 'fineagg' comprises of large values
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=df, x='age') # most of the data in 'age' column lies in b/w 28
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.swarmplot(data=df, y='cement')
# Out:
# C:\Users\ironm\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:ylabel='cement'>

# %%
sns.swarmplot(data=df, y='water')
# Out:
# C:\Users\ironm\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 19.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:ylabel='water'>

# %%
sns.swarmplot(data=df, y='superplastic') # the dots we can see at 0 value
# Out:
# C:\Users\ironm\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:ylabel='superplastic'>

# %%
sns.FacetGrid(df, hue='age', size=5).map(plt.scatter, "cement",'slag').add_legend()
# Out:
# C:\Users\ironm\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
a4_dims = (10,5)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.barplot(data=df, x = 'age', y = 'strength')
# Out:
# <AxesSubplot:xlabel='age', ylabel='strength'>

# %%
a4_dims = (10,5)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.barplot(data=df, x = 'age', y = 'superplastic')
# Out:
# <AxesSubplot:xlabel='age', ylabel='superplastic'>

# %%
a4_dims = (10,5)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.barplot(data=df, x = 'age', y = 'ash')
# Out:
# <AxesSubplot:xlabel='age', ylabel='ash'>

# %%
a4_dims = (18,8)
fig, ax = pyplot.subplots(figsize=a4_dims)
df.groupby(['age'])['fineagg'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
df.sort_values(['age','strength'], ascending = True)[150:200] 

# here the values are in ascending order according to the age and strength column
# try out with only single vairable, the order will be changed
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 391    170.3  155.5    0.0  185.7           0.0     1026.6    724.3    7
# 1020   183.9  122.6    0.0  203.5           0.0      959.2    800.0    7
# 362    225.0    0.0    0.0  181.0           0.0     1113.0    833.0    7
# 664    173.0  116.0    0.0  192.0           0.0      946.8    856.8    7
# 154    252.0    0.0    0.0  186.0           0.0     1111.0    784.0    7
# 475    382.0    0.0    0.0  186.0           0.0     1111.0    784.0    7
# 698    252.5    0.0    0.0  185.7           0.0     1111.6    784.3    7
# 217    203.5  135.7    0.0  185.7           0.0     1076.2    759.3    7
# 111    238.0    0.0    0.0  186.0           0.0     1119.0    789.0    7
# 287    181.9  272.8    0.0  185.7           0.0     1012.4    714.3    7
# 659    250.0    0.0    0.0  182.0           0.0     1100.0    820.0    7
# 728    220.8  147.2    0.0  185.7           0.0     1055.0    744.3    7
# ...

# %%
df.groupby('age').count().plot(kind='bar')

# all particles which lie on 28 is more high
# it shows most of the materials are suitable for age 28 to get strength
# Out:
# <AxesSubplot:xlabel='age'>

# %%
df['age'].sum()/len(df['age'])

# avg age strength of concrete
# Out:
# 45.662135922330094

# %%
sns.countplot(data=df, x='age')

# count of each value available in age column

# particularly i selected age column because to know where most of the particles took certain age to get strength
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
df.hist(bins=50, figsize = (10,10)) # from the graphs we can observe the 'strength' and 'cement' values are distributed quiet perfectly
# Out:
# array([[<AxesSubplot:title={'center':'cement'}>,
#         <AxesSubplot:title={'center':'slag'}>,
#         <AxesSubplot:title={'center':'ash'}>],
#        [<AxesSubplot:title={'center':'water'}>,
#         <AxesSubplot:title={'center':'superplastic'}>,
#         <AxesSubplot:title={'center':'coarseagg'}>],
#        [<AxesSubplot:title={'center':'fineagg'}>,
#         <AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'strength'}>]], dtype=object)

# %%
df.mean() # mean of each column, here coarseagg feature has highest mean because of very distinct values
# Out:
# cement          281.167864
# slag             73.895825
# ash              54.188350
# water           181.567282
# superplastic      6.204660
# coarseagg       972.918932
# fineagg         773.580485
# age              45.662136
# strength         35.817961
# dtype: float64

# %%
df.mean().plot(figsize=(10,5)) 
# from the plot we clearly observe that 'coarseagg' and 'fineagg' columns have large value than the other feature values
# which in the sense the plot for those two columns have raised very high because of large values
# Out:
# <AxesSubplot:>

# %%
df.median().plot(figsize=(10,4)) # plot the median values from columns,plot represents that how columns have distint values
# Out:
# <AxesSubplot:>

# %%
df.std().plot(figsize=(10,4)) #
# Out:
# <AxesSubplot:>

# %%
df['age'].value_counts()/len(df['age']) # it gives the output of how each value of the feauture is distributed among the total values in the column
# Out:
# 28     0.412621
# 3      0.130097
# 7      0.122330
# 56     0.088350
# 14     0.060194
# 90     0.052427
# 100    0.050485
# 180    0.025243
# 91     0.021359
# 365    0.013592
# 270    0.012621
# 360    0.005825
# 120    0.002913
# 1      0.001942
# Name: age, dtype: float64

# %%
corr_matrix=df.corr()
print(corr_matrix["age"].sort_values(ascending=False))
corr_matrix["age"].sort_values(ascending=False).plot(figsize=(8,4)) # change the column and try out

# this gives the relationship with a particular column
# Out:
# age             1.000000
# strength        0.328873
# water           0.277618
# cement          0.081946
# coarseagg      -0.003016
# slag           -0.044246
# ash            -0.154371
# fineagg        -0.156095
# superplastic   -0.192700
# Name: age, dtype: float64
# <AxesSubplot:>

# %%
from pandas.plotting import scatter_matrix

cols  = ['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
       'fineagg', 'age', 'strength']

scatter_matrix(df[cols], figsize=(10,10))

# the plot shows that how much one variable is affected by another or the relationship between them.
# Out:
# array([[<AxesSubplot:xlabel='cement', ylabel='cement'>,
#         <AxesSubplot:xlabel='slag', ylabel='cement'>,
#         <AxesSubplot:xlabel='ash', ylabel='cement'>,
#         <AxesSubplot:xlabel='water', ylabel='cement'>,
#         <AxesSubplot:xlabel='superplastic', ylabel='cement'>,
#         <AxesSubplot:xlabel='coarseagg', ylabel='cement'>,
#         <AxesSubplot:xlabel='fineagg', ylabel='cement'>,
#         <AxesSubplot:xlabel='age', ylabel='cement'>,
#         <AxesSubplot:xlabel='strength', ylabel='cement'>],
#        [<AxesSubplot:xlabel='cement', ylabel='slag'>,
#         <AxesSubplot:xlabel='slag', ylabel='slag'>,
#         <AxesSubplot:xlabel='ash', ylabel='slag'>,
#         <AxesSubplot:xlabel='water', ylabel='slag'>,
#         <AxesSubplot:xlabel='superplastic', ylabel='slag'>,
#         <AxesSubplot:xlabel='coarseagg', ylabel='slag'>,
#         <AxesSubplot:xlabel='fineagg', ylabel='slag'>,
#         <AxesSubplot:xlabel='age', ylabel='slag'>,
# ...

# %%
df.columns
# Out:
# Index(['cement', 'slag', 'ash', 'water', 'superplastic', 'coarseagg',
#        'fineagg', 'age', 'strength'],
#       dtype='object')

# %% [markdown]
# ## MODEL BUILDING

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.svm import LinearSVR, SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor

from sklearn.model_selection import GridSearchCV

# %% [markdown]
# we are using different regressors to know which performs the best

# %%
y = df['strength'].copy()
X = df.drop('strength', axis=1)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)
    
    
# Scale X with a standard scaler
scaler = StandardScaler()
scaler.fit(X_train)
    
X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.svm import LinearSVR, SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor

# %%
models = {
    "                     Linear Regression": LinearRegression(),
    "                 L2 (Ridge) Regression": Ridge(),
    "Support Vector Machine (Linear Kernel)": LinearSVR(),
    "   Support Vector Mahcine (RBF Kernel)": SVR(),
    "                         Decision Tree": DecisionTreeRegressor(),
    "                        Neural Network": MLPRegressor(),
    "                         Random Forest": RandomForestRegressor(),
    "                     Gradient Boosting": GradientBoostingRegressor(),
    "                              AdaBoost": AdaBoostRegressor()
}

for name, model in models.items():
    model.fit(X_train, y_train)
    print(name + " trained.")
# Out:
#                      Linear Regression trained.
#                  L2 (Ridge) Regression trained.
# Support Vector Machine (Linear Kernel) trained.
#    Support Vector Mahcine (RBF Kernel) trained.
#                          Decision Tree trained.
# C:\Users\ironm\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#                         Neural Network trained.
#                          Random Forest trained.
#                      Gradient Boosting trained.
#                               AdaBoost trained.

# %% [markdown]
# ### Feature Importance

# %%
model = GradientBoostingRegressor() # try out and change with different regressors, feature_importances will get changed
model.fit(X_train,y_train)

model.feature_importances_
# Out:
# array([0.31179006, 0.0662244 , 0.01619948, 0.09029667, 0.08819967,
#        0.01741114, 0.03751883, 0.37235975])

# %%
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 0.31179
# Feature: 1, Score: 0.06622
# Feature: 2, Score: 0.01620
# Feature: 3, Score: 0.09030
# Feature: 4, Score: 0.08820
# Feature: 5, Score: 0.01741
# Feature: 6, Score: 0.03752
# Feature: 7, Score: 0.37236

# %%
feature_imp = pd.Series(model.feature_importances_, df.columns[:-1]).sort_values()
feature_imp.plot(kind='barh', title='Feature Importances')
plt.xlabel('Feature Importance Score')
# Out:
# Text(0.5, 0, 'Feature Importance Score')

# %%
for name, model in models.items():
    print(name + " R^2: {:.5f}".format(model.score(X_test, y_test)))
# Out:
#                      Linear Regression R^2: 0.63896
#                  L2 (Ridge) Regression R^2: 0.63794
# Support Vector Machine (Linear Kernel) R^2: 0.63343
#    Support Vector Mahcine (RBF Kernel) R^2: 0.63488
#                          Decision Tree R^2: 0.84070
#                         Neural Network R^2: 0.47081
#                          Random Forest R^2: 0.91168
#                      Gradient Boosting R^2: 0.90597
#                               AdaBoost R^2: 0.79646

# %%
best_model = GradientBoostingRegressor() 
best_model.fit(X_train, y_train)

print("Model R^2 (Before Optimization): {:.5f}".format(best_model.score(X_test, y_test)))
# Out:
# Model R^2 (Before Optimization): 0.90586

# %%
params = { 'learning_rate': [0.01, 0.1, 1.0],
           'n_estimators': [100, 150, 200],
           'max_depth': [3, 4, 5] }

clf = GridSearchCV(best_model, params)
clf.fit(X_train, y_train)

clf.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200}

# %%
params = {  'learning_rate': [0.01, 0.1, 1.0],
            'n_estimators': [100, 150, 200],
            'max_depth': [3, 4, 5] }

clf = GridSearchCV(best_model, params)
clf.fit(X_train, y_train)

clf.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200}

# %% [markdown]
# I found GradientBoostRegressor works more efficiently, which also provides the predominent features which performed well with the other features and with the target.
#
# where as the GradientBoostRegressor is a boosting technique which performed the residual error perfectly to give the best score for the testing data.
#
# Data distribution was found to be not defined perfectly because of raw and some unstructured way the data was presented. But to perform the regression, the data has been scaled and transformed for the training purpose.
#
# strength column is been took as the target variable and the other variables as features.
#
# from feature_importances_ we noticed cement, age are the most significant variables which contributed for the target variable.
